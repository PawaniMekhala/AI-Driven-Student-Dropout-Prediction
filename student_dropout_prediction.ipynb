# %% [markdown]
# <a href="https://colab.research.google.com/github/PawaniMekhala/AI-Driven-Student-Dropout-Prediction/blob/main/student_dropout_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# create project folder structure

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# create the project folder inside Drive:
# !mkdir -p /content/drive/MyDrive/student-dropout-prediction

# %%
# Create Root Project Folder
# !mkdir -p student-dropout-prediction

# %%
# Create Subfolders
# !mkdir -p student-dropout-prediction/data/raw
# !mkdir -p student-dropout-prediction/data/processed

# !mkdir -p student-dropout-prediction/notebooks

# !mkdir -p student-dropout-prediction/results/figures
# !mkdir -p student-dropout-prediction/results/metrics

# !mkdir -p student-dropout-prediction/models/logistic_regression
# !mkdir -p student-dropout-prediction/models/random_forest
# !mkdir -p student-dropout-prediction/models/xgboost

# %%
# Verify Folder Structure
# !find student-dropout-prediction
# Out:
# student-dropout-prediction
# student-dropout-prediction/results
# student-dropout-prediction/results/figures
# student-dropout-prediction/results/metrics
# student-dropout-prediction/data
# student-dropout-prediction/data/raw
# student-dropout-prediction/data/processed
# student-dropout-prediction/notebooks
# student-dropout-prediction/models
# student-dropout-prediction/models/logistic_regression
# student-dropout-prediction/models/random_forest
# student-dropout-prediction/models/xgboost

# %%
# List folders in MyDrive
# !ls /content/drive/MyDrive

# Go inside your project folder
# !ls /content/drive/MyDrive/student-dropout-prediction

# Check raw data folder
# !ls /content/drive/MyDrive/student-dropout-prediction/data/raw
# Out:
# 'Colab Notebooks'   student-dropout-prediction
# data  models  notebooks  results
# data.csv

# %%
# !ls /content/drive/MyDrive/student-dropout-prediction/data/raw
# Out:
# data.csv

# %%
# to make this permanent in Google Drive Copy your project folder to Drive:
# !cp -r student-dropout-prediction /content/drive/MyDrive/

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"

# %%
# !mv "/content/drive/MyDrive/Colab Notebooks/"*.ipynb \
#     "/content/drive/MyDrive/student-dropout-prediction/notebooks/"
# Out:
# mv: cannot stat '/content/drive/MyDrive/Colab Notebooks/*.ipynb': No such file or directory

# %%
# !ls "/content/drive/MyDrive/student-dropout-prediction/notebooks"
# Out:
# 01_data_exploration.ipynb  05_ensemble_model.ipynb
# 02_preprocessing.ipynb	   06_explainability_SHAP.ipynb
# 03_baseline_models.ipynb   student-dropout-prediction.ipynb
# 04_advanced_models.ipynb
